# %%
# %load_ext sql

# %%
import csv, sqlite3
import pandas as pd

# %%
con = sqlite3.connect("my_data1.db")
cur = con.cursor()

# %%
# %sql sqlite:///my_data1.db

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv")
df.to_sql("SPACEXTBL", con, if_exists='replace', index=False,method="multi")
# Out:
# /Users/zahrataghadomi/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:2872: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(

# %%
# %sql create table SPACEXTABLE as select * from SPACEXTBL where Date is not null
# Out:
#  * sqlite:///my_data1.db
# (sqlite3.OperationalError) table SPACEXTABLE already exists
# [SQL: create table SPACEXTABLE as select * from SPACEXTBL where Date is not null]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
df
# Out:
#            Date Time (UTC) Booster_Version   Launch_Site  \
# 0    2010-06-04   18:45:00  F9 v1.0  B0003   CCAFS LC-40
# 1    2010-12-08   15:43:00  F9 v1.0  B0004   CCAFS LC-40
# 2    2012-05-22    7:44:00  F9 v1.0  B0005   CCAFS LC-40
# 3    2012-10-08    0:35:00  F9 v1.0  B0006   CCAFS LC-40
# 4    2013-03-01   15:10:00  F9 v1.0  B0007   CCAFS LC-40
# ..          ...        ...             ...           ...
# 96   2020-11-05   23:24:23    F9 B5B1062.1  CCAFS SLC-40
# 97   2020-11-16    0:27:00   F9 B5B1061.1     KSC LC-39A
# 98   2020-11-21   17:17:08    F9 B5B1063.1   VAFB SLC-4E
# 99   2020-11-25    2:13:00  F9 B5 B1049.7   CCAFS SLC-40
# 100  2020-12-06   16:17:08  F9 B5 B1058.4     KSC LC-39A
#
#                                                Payload  PAYLOAD_MASS__KG_  \
# 0                 Dragon Spacecraft Qualification Unit                  0
# 1    Dragon demo flight C1, two CubeSats, barrel of...                  0
# ...

# %% [markdown]
# ### Task 1

# %%
# %sql select DISTINCT(Launch_Site) from SPACEXTBL
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('CCAFS LC-40',), ('VAFB SLC-4E',), ('KSC LC-39A',), ('CCAFS SLC-40',)]

# %% [markdown]
# ### Task 2

# %%
# %sql select * from SPACEXTBL where Launch_Site like '%CCA%' limit 5
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('2010-06-04', '18:45:00', 'F9 v1.0  B0003', 'CCAFS LC-40', 'Dragon Spacecraft Qualification Unit', 0, 'LEO', 'SpaceX', 'Success', 'Failure (parachute)'),
#  ('2010-12-08', '15:43:00', 'F9 v1.0  B0004', 'CCAFS LC-40', 'Dragon demo flight C1, two CubeSats, barrel of Brouere cheese', 0, 'LEO (ISS)', 'NASA (COTS) NRO', 'Success', 'Failure (parachute)'),
#  ('2012-05-22', '7:44:00', 'F9 v1.0  B0005', 'CCAFS LC-40', 'Dragon demo flight C2', 525, 'LEO (ISS)', 'NASA (COTS)', 'Success', 'No attempt'),
#  ('2012-10-08', '0:35:00', 'F9 v1.0  B0006', 'CCAFS LC-40', 'SpaceX CRS-1', 500, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt'),
#  ('2013-03-01', '15:10:00', 'F9 v1.0  B0007', 'CCAFS LC-40', 'SpaceX CRS-2', 677, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt')]

# %% [markdown]
# ### Task 3

# %%
# %sql select  Customer, SUM(PAYLOAD_MASS__KG_) as "total payload mass" from SPACEXTBL where Customer = 'NASA (CRS)'
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('NASA (CRS)', 45596)]

# %% [markdown]
# ### Task 4

# %%
# %sql select Booster_Version, AVG(PAYLOAD_MASS__KG_) as "Average Playload Mass" from SPACEXTBL where Booster_Version like '%F9 v1.1%'
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 v1.1  B1003', 2534.6666666666665)]

# %% [markdown]
# ### Task 5

# %%
# %sql select MIN(Date) as Date from SPACEXTBL where Landing_Outcome = 'Success (ground pad)'
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('2015-12-22',)]

# %% [markdown]
# ### Task 6

# %%
# %sql select Booster_Version, Landing_Outcome, PAYLOAD_MASS__KG_ from SPACEXTBL where PAYLOAD_MASS__KG_ BETWEEN 4000 AND 6000 and Landing_Outcome = 'Success (drone ship)'
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 FT B1022', 'Success (drone ship)', 4696),
#  ('F9 FT B1026', 'Success (drone ship)', 4600),
#  ('F9 FT  B1021.2', 'Success (drone ship)', 5300),
#  ('F9 FT  B1031.2', 'Success (drone ship)', 5200)]

# %% [markdown]
# ### Task 7

# %%
# %sql select COUNT(Mission_Outcome), Mission_Outcome from SPACEXTBL GROUP BY Mission_Outcome
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(1, 'Failure (in flight)'),
#  (98, 'Success'),
#  (1, 'Success '),
#  (1, 'Success (payload status unclear)')]

# %% [markdown]
# ### Task 8

# %%
# %sql select Booster_Version, MAX(PAYLOAD_MASS__KG_) from SPACEXTBL GROUP BY Booster_Version
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 B4  B1039.2', 2647),
#  ('F9 B4  B1040.2', 5384),
#  ('F9 B4  B1041.2', 9600),
#  ('F9 B4  B1043.2', 6460),
#  ('F9 B4 B1039.1', 3310),
#  ('F9 B4 B1040.1', 4990),
#  ('F9 B4 B1041.1', 9600),
#  ('F9 B4 B1042.1', 3500),
#  ('F9 B4 B1043.1', 5000),
#  ('F9 B4 B1044', 6092),
#  ('F9 B4 B1045.1', 362),
#  ('F9 B4 B1045.2', 2697),
#  ('F9 B5  B1046.1', 3600),
#  ('F9 B5 B1046.2', 5800),
#  ('F9 B5 B1046.3', 4000),
#  ('F9 B5 B1046.4', 12050),
#  ('F9 B5 B1047.2', 5300),
#  ('F9 B5 B1047.3 ', 6500),
#  ('F9 B5 B1048.2', 3000),
#  ('F9 B5 B1048.3', 4850),
#  ('F9 B5 B1048.4', 15600),
#  ('F9 B5 B1048.5', 15600),
#  ('F9 B5 B1049.2', 9600),
#  ('F9 B5 B1049.3', 13620),
#  ('F9 B5 B1049.4', 15600),
#  ('F9 B5 B1049.5', 15600),
#  ('F9 B5 B1049.6', 15440),
#  ('F9 B5 B1049.7 ', 15600),
#  ('F9 B5 B1051.2 ', 4200),
#  ('F9 B5 B1051.3', 15600),
#  ('F9 B5 B1051.4', 15600),
#  ('F9 B5 B1051.5', 14932),
#  ('F9 B5 B1051.6', 15600),
# ...

# %% [markdown]
# ### Task 9

# %%
# %sql select SUBSTR(Date, 6,2) as month, Booster_Version, Launch_Site, Landing_Outcome from SPACEXTBL where SUBSTR(Date,0,5)='2015' and Landing_Outcome = 'Failure (drone ship)'
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('01', 'F9 v1.1 B1012', 'CCAFS LC-40', 'Failure (drone ship)'),
#  ('04', 'F9 v1.1 B1015', 'CCAFS LC-40', 'Failure (drone ship)')]

# %% [markdown]
# ### Task 10

# %%
# %sql select Landing_Outcome, COUNT(Landing_Outcome) as Count from SPACEXTBL WHERE Date BETWEEN  "2010-06-04" AND "2017-03-20" GROUP BY Landing_Outcome ORDER BY COUNT(Landing_Outcome) desc
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('No attempt', 10),
#  ('Success (drone ship)', 5),
#  ('Failure (drone ship)', 5),
#  ('Success (ground pad)', 3),
#  ('Controlled (ocean)', 3),
#  ('Uncontrolled (ocean)', 2),
#  ('Failure (parachute)', 2),
#  ('Precluded (drone ship)', 1)]
